# %% [markdown]
# #### Please check the previously saved versions of this notebook on - https://github.com/AvtnshM/SSL

# %%
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

cudnn.benchmark = True
# Out:
# Using device: cuda

# %%
# CIFAR10 normalization values
cifar_mean = (0.4914, 0.4822, 0.4465)
cifar_std = (0.2023, 0.1994, 0.2010)

ssl_transform = transforms.Compose([
    transforms.RandomResizedCrop(32, scale=(0.2, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([
        transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)
    ], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.GaussianBlur(3),
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std)
])

# %%
class BYOLDataset(torch.utils.data.Dataset):
    def __init__(self, root, train, transform):
        self.dataset = datasets.CIFAR10(
            root=root,
            train=train,
            download=True,
            transform=None  # IMPORTANT: no transform here
        )
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, _ = self.dataset[idx]   # img is PIL image
        view1 = self.transform(img)
        view2 = self.transform(img)
        return view1, view2


ssl_dataset = BYOLDataset(
    root="/kaggle/working/data",
    train=True,
    transform=ssl_transform
)

# %%
loader = DataLoader(
    ssl_dataset,
    batch_size=512,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)

print("Batches per epoch:", len(loader))
# Out:
# Batches per epoch: 97

# %%
import torchvision.models as models

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()

        # Load ResNet18
        backbone = models.resnet18(weights=None)

        # Remove final classification layer
        self.encoder = nn.Sequential(*list(backbone.children())[:-1])

    def forward(self, x):
        x = self.encoder(x)
        return x.view(x.size(0), -1)  # Output: (B, 512)

# %%
class Predictor(nn.Module):
    def __init__(self, dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.ReLU(),
            nn.Linear(dim, dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
class Projector(nn.Module):
    def __init__(self, in_dim=512, hidden_dim=512, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
def ssl_loss(p, z):
    p = F.normalize(p, dim=1)
    z = F.normalize(z, dim=1)
    return F.mse_loss(p, z)

# %%
encoder = Encoder().to(device)
projector = Projector().to(device)
predictor = Predictor().to(device)

target_encoder = Encoder().to(device)
target_encoder.load_state_dict(encoder.state_dict())

for p in target_encoder.parameters():
    p.requires_grad = False

optimizer = torch.optim.Adam(
    list(encoder.parameters()) +
    list(projector.parameters()) +
    list(predictor.parameters()),
    lr=1e-3
)

ema_tau = 0.996

# %%
@torch.no_grad()
def feature_variance(z):
    return z.var(dim=0).mean().item()

@torch.no_grad()
def cosine_similarity_mean(z1, z2):
    z1 = F.normalize(z1, dim=1)
    z2 = F.normalize(z2, dim=1)
    return (z1 * z2).sum(dim=1).mean().item()

@torch.no_grad()
def update_target_encoder(online, target, tau):
    for op, tp in zip(online.parameters(), target.parameters()):
        tp.data = tau * tp.data + (1 - tau) * op.data

# %%
epochs = 200
os.makedirs("/kaggle/working/checkpoints", exist_ok=True)

total_start_time = time.time()

for epoch in range(epochs):

    epoch_start = time.time()

    total_loss, total_var, total_cos = 0.0, 0.0, 0.0

    for view1, view2 in loader:

        view1 = view1.to(device)
        view2 = view2.to(device)

        z1 = encoder(view1)
        z2 = encoder(view2)

        h1 = projector(z1)
        h2 = projector(z2)

        p1 = predictor(h1)
        p2 = predictor(h2)

        with torch.no_grad():
            t1 = projector(target_encoder(view1))
            t2 = projector(target_encoder(view2))

        loss = ssl_loss(p1, t2.detach()) + ssl_loss(p2, t1.detach())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        update_target_encoder(encoder, target_encoder, ema_tau)

        with torch.no_grad():
            total_var += feature_variance(z1)
            total_cos += cosine_similarity_mean(z1, z2)

        total_loss += loss.item()

    epoch_time = (time.time() - epoch_start) / 60
    total_time = (time.time() - total_start_time) / 60

    print(
        f"Epoch {epoch+1}/{epochs} | "
        f"Loss {total_loss/len(loader):.4f} | "
        f"Var {total_var/len(loader):.4f} | "
        f"Cos {total_cos/len(loader):.4f} | "
        f"Epoch Time {epoch_time:.2f} min | "
        f"Total Time {total_time:.2f} min"
    )

# Save only final model (avoid 5GB explosion)
torch.save(encoder.state_dict(), "/kaggle/working/encoder_final.pt")
# Out:
# Epoch 1/200 | Loss 0.0013 | Var 2.2641 | Cos 0.6690 | Epoch Time 1.16 min | Total Time 1.16 min
# Epoch 2/200 | Loss 0.0007 | Var 2.2287 | Cos 0.6967 | Epoch Time 1.11 min | Total Time 2.27 min
# Epoch 3/200 | Loss 0.0009 | Var 2.1925 | Cos 0.7441 | Epoch Time 1.12 min | Total Time 3.39 min
# Epoch 4/200 | Loss 0.0009 | Var 2.1353 | Cos 0.7614 | Epoch Time 1.12 min | Total Time 4.51 min
# Epoch 5/200 | Loss 0.0010 | Var 2.1059 | Cos 0.7807 | Epoch Time 1.11 min | Total Time 5.62 min
# Epoch 6/200 | Loss 0.0010 | Var 2.0485 | Cos 0.7935 | Epoch Time 1.11 min | Total Time 6.73 min
# Epoch 7/200 | Loss 0.0010 | Var 1.9872 | Cos 0.8036 | Epoch Time 1.11 min | Total Time 7.84 min
# Epoch 8/200 | Loss 0.0010 | Var 1.9468 | Cos 0.8160 | Epoch Time 1.11 min | Total Time 8.95 min
# Epoch 9/200 | Loss 0.0010 | Var 1.9306 | Cos 0.8212 | Epoch Time 1.11 min | Total Time 10.07 min
# Epoch 10/200 | Loss 0.0011 | Var 1.9187 | Cos 0.8289 | Epoch Time 1.11 min | Total Time 11.18 min
# Epoch 11/200 | Loss 0.0011 | Var 1.9088 | Cos 0.8325 | Epoch Time 1.12 min | Total Time 12.30 min
# Epoch 12/200 | Loss 0.0011 | Var 1.9000 | Cos 0.8374 | Epoch Time 1.11 min | Total Time 13.41 min
# Epoch 13/200 | Loss 0.0011 | Var 1.8888 | Cos 0.8405 | Epoch Time 1.12 min | Total Time 14.53 min
# Epoch 14/200 | Loss 0.0011 | Var 1.8628 | Cos 0.8461 | Epoch Time 1.12 min | Total Time 15.65 min
# Epoch 15/200 | Loss 0.0011 | Var 1.8340 | Cos 0.8496 | Epoch Time 1.12 min | Total Time 16.77 min
# Epoch 16/200 | Loss 0.0011 | Var 1.8319 | Cos 0.8510 | Epoch Time 1.11 min | Total Time 17.88 min
# Epoch 17/200 | Loss 0.0012 | Var 1.8003 | Cos 0.8533 | Epoch Time 1.12 min | Total Time 19.00 min
# Epoch 18/200 | Loss 0.0012 | Var 1.7928 | Cos 0.8543 | Epoch Time 1.11 min | Total Time 20.12 min
# Epoch 19/200 | Loss 0.0012 | Var 1.7914 | Cos 0.8569 | Epoch Time 1.12 min | Total Time 21.23 min
# Epoch 20/200 | Loss 0.0012 | Var 1.7828 | Cos 0.8584 | Epoch Time 1.12 min | Total Time 22.35 min
# Epoch 21/200 | Loss 0.0012 | Var 1.7727 | Cos 0.8611 | Epoch Time 1.11 min | Total Time 23.47 min
# Epoch 22/200 | Loss 0.0013 | Var 1.7584 | Cos 0.8603 | Epoch Time 1.12 min | Total Time 24.58 min
# Epoch 23/200 | Loss 0.0013 | Var 1.7311 | Cos 0.8627 | Epoch Time 1.12 min | Total Time 25.70 min
# Epoch 24/200 | Loss 0.0013 | Var 1.7344 | Cos 0.8650 | Epoch Time 1.12 min | Total Time 26.83 min
# Epoch 25/200 | Loss 0.0013 | Var 1.7218 | Cos 0.8659 | Epoch Time 1.11 min | Total Time 27.94 min
# Epoch 26/200 | Loss 0.0013 | Var 1.7088 | Cos 0.8670 | Epoch Time 1.12 min | Total Time 29.06 min
# Epoch 27/200 | Loss 0.0013 | Var 1.6982 | Cos 0.8684 | Epoch Time 1.12 min | Total Time 30.18 min
# Epoch 28/200 | Loss 0.0013 | Var 1.6843 | Cos 0.8696 | Epoch Time 1.12 min | Total Time 31.29 min
# Epoch 29/200 | Loss 0.0013 | Var 1.6679 | Cos 0.8705 | Epoch Time 1.13 min | Total Time 32.42 min
# Epoch 30/200 | Loss 0.0013 | Var 1.6438 | Cos 0.8714 | Epoch Time 1.12 min | Total Time 33.54 min
# Epoch 31/200 | Loss 0.0013 | Var 1.6317 | Cos 0.8710 | Epoch Time 1.13 min | Total Time 34.67 min
# Epoch 32/200 | Loss 0.0013 | Var 1.6254 | Cos 0.8712 | Epoch Time 1.13 min | Total Time 35.79 min
# Epoch 33/200 | Loss 0.0013 | Var 1.6129 | Cos 0.8722 | Epoch Time 1.13 min | Total Time 36.92 min
# Epoch 34/200 | Loss 0.0013 | Var 1.5989 | Cos 0.8724 | Epoch Time 1.13 min | Total Time 38.05 min
# Epoch 35/200 | Loss 0.0013 | Var 1.5853 | Cos 0.8735 | Epoch Time 1.13 min | Total Time 39.18 min
# Epoch 36/200 | Loss 0.0013 | Var 1.5782 | Cos 0.8740 | Epoch Time 1.13 min | Total Time 40.31 min
# Epoch 37/200 | Loss 0.0013 | Var 1.5701 | Cos 0.8738 | Epoch Time 1.12 min | Total Time 41.43 min
# Epoch 38/200 | Loss 0.0013 | Var 1.5638 | Cos 0.8738 | Epoch Time 1.12 min | Total Time 42.56 min
# Epoch 39/200 | Loss 0.0012 | Var 1.5541 | Cos 0.8751 | Epoch Time 1.13 min | Total Time 43.68 min
# Epoch 40/200 | Loss 0.0012 | Var 1.5413 | Cos 0.8750 | Epoch Time 1.12 min | Total Time 44.81 min
# Epoch 41/200 | Loss 0.0012 | Var 1.5340 | Cos 0.8759 | Epoch Time 1.11 min | Total Time 45.92 min
# Epoch 42/200 | Loss 0.0012 | Var 1.5174 | Cos 0.8762 | Epoch Time 1.12 min | Total Time 47.04 min
# Epoch 43/200 | Loss 0.0012 | Var 1.5109 | Cos 0.8762 | Epoch Time 1.12 min | Total Time 48.17 min
# Epoch 44/200 | Loss 0.0012 | Var 1.4994 | Cos 0.8776 | Epoch Time 1.12 min | Total Time 49.28 min
# Epoch 45/200 | Loss 0.0012 | Var 1.4938 | Cos 0.8770 | Epoch Time 1.12 min | Total Time 50.41 min
# Epoch 46/200 | Loss 0.0012 | Var 1.4958 | Cos 0.8762 | Epoch Time 1.12 min | Total Time 51.53 min
# Epoch 47/200 | Loss 0.0012 | Var 1.4893 | Cos 0.8782 | Epoch Time 1.12 min | Total Time 52.65 min
# Epoch 48/200 | Loss 0.0012 | Var 1.4805 | Cos 0.8780 | Epoch Time 1.12 min | Total Time 53.77 min
# Epoch 49/200 | Loss 0.0012 | Var 1.4783 | Cos 0.8791 | Epoch Time 1.12 min | Total Time 54.89 min
# Epoch 50/200 | Loss 0.0012 | Var 1.4809 | Cos 0.8781 | Epoch Time 1.13 min | Total Time 56.02 min
# Epoch 51/200 | Loss 0.0012 | Var 1.4735 | Cos 0.8790 | Epoch Time 1.12 min | Total Time 57.14 min
# Epoch 52/200 | Loss 0.0012 | Var 1.4772 | Cos 0.8787 | Epoch Time 1.12 min | Total Time 58.26 min
# Epoch 53/200 | Loss 0.0012 | Var 1.4680 | Cos 0.8785 | Epoch Time 1.12 min | Total Time 59.37 min
# Epoch 54/200 | Loss 0.0012 | Var 1.4616 | Cos 0.8800 | Epoch Time 1.12 min | Total Time 60.49 min
# Epoch 55/200 | Loss 0.0012 | Var 1.4488 | Cos 0.8801 | Epoch Time 1.11 min | Total Time 61.60 min
# Epoch 56/200 | Loss 0.0012 | Var 1.4431 | Cos 0.8790 | Epoch Time 1.12 min | Total Time 62.72 min
# Epoch 57/200 | Loss 0.0012 | Var 1.4417 | Cos 0.8790 | Epoch Time 1.12 min | Total Time 63.84 min
# Epoch 58/200 | Loss 0.0012 | Var 1.4387 | Cos 0.8801 | Epoch Time 1.12 min | Total Time 64.96 min
# Epoch 59/200 | Loss 0.0012 | Var 1.4320 | Cos 0.8795 | Epoch Time 1.12 min | Total Time 66.08 min
# Epoch 60/200 | Loss 0.0012 | Var 1.4217 | Cos 0.8787 | Epoch Time 1.12 min | Total Time 67.20 min
# Epoch 61/200 | Loss 0.0012 | Var 1.4248 | Cos 0.8797 | Epoch Time 1.11 min | Total Time 68.31 min
# Epoch 62/200 | Loss 0.0012 | Var 1.4230 | Cos 0.8798 | Epoch Time 1.12 min | Total Time 69.43 min
# Epoch 63/200 | Loss 0.0012 | Var 1.4206 | Cos 0.8801 | Epoch Time 1.11 min | Total Time 70.55 min
# Epoch 64/200 | Loss 0.0012 | Var 1.4227 | Cos 0.8792 | Epoch Time 1.12 min | Total Time 71.67 min
# Epoch 65/200 | Loss 0.0012 | Var 1.4128 | Cos 0.8799 | Epoch Time 1.11 min | Total Time 72.77 min
# Epoch 66/200 | Loss 0.0012 | Var 1.4116 | Cos 0.8798 | Epoch Time 1.12 min | Total Time 73.89 min
# Epoch 67/200 | Loss 0.0012 | Var 1.4051 | Cos 0.8809 | Epoch Time 1.11 min | Total Time 75.01 min
# Epoch 68/200 | Loss 0.0012 | Var 1.4021 | Cos 0.8806 | Epoch Time 1.12 min | Total Time 76.12 min
# Epoch 69/200 | Loss 0.0012 | Var 1.4017 | Cos 0.8810 | Epoch Time 1.12 min | Total Time 77.25 min
# Epoch 70/200 | Loss 0.0011 | Var 1.4012 | Cos 0.8817 | Epoch Time 1.12 min | Total Time 78.37 min
# Epoch 71/200 | Loss 0.0011 | Var 1.3987 | Cos 0.8818 | Epoch Time 1.13 min | Total Time 79.50 min
# Epoch 72/200 | Loss 0.0011 | Var 1.3896 | Cos 0.8817 | Epoch Time 1.13 min | Total Time 80.63 min
# Epoch 73/200 | Loss 0.0011 | Var 1.3791 | Cos 0.8820 | Epoch Time 1.11 min | Total Time 81.74 min
# Epoch 74/200 | Loss 0.0011 | Var 1.3891 | Cos 0.8818 | Epoch Time 1.11 min | Total Time 82.85 min
# Epoch 75/200 | Loss 0.0011 | Var 1.3921 | Cos 0.8812 | Epoch Time 1.12 min | Total Time 83.97 min
# Epoch 76/200 | Loss 0.0011 | Var 1.3888 | Cos 0.8816 | Epoch Time 1.12 min | Total Time 85.10 min
# Epoch 77/200 | Loss 0.0011 | Var 1.3910 | Cos 0.8805 | Epoch Time 1.13 min | Total Time 86.23 min
# Epoch 78/200 | Loss 0.0011 | Var 1.3826 | Cos 0.8817 | Epoch Time 1.12 min | Total Time 87.35 min
# Epoch 79/200 | Loss 0.0011 | Var 1.3799 | Cos 0.8826 | Epoch Time 1.12 min | Total Time 88.47 min
# Epoch 80/200 | Loss 0.0011 | Var 1.3763 | Cos 0.8814 | Epoch Time 1.11 min | Total Time 89.58 min
# Epoch 81/200 | Loss 0.0011 | Var 1.3745 | Cos 0.8813 | Epoch Time 1.11 min | Total Time 90.69 min
# Epoch 82/200 | Loss 0.0011 | Var 1.3778 | Cos 0.8811 | Epoch Time 1.11 min | Total Time 91.80 min
# Epoch 83/200 | Loss 0.0011 | Var 1.3680 | Cos 0.8810 | Epoch Time 1.12 min | Total Time 92.92 min
# Epoch 84/200 | Loss 0.0011 | Var 1.3691 | Cos 0.8813 | Epoch Time 1.13 min | Total Time 94.05 min
# Epoch 85/200 | Loss 0.0011 | Var 1.3652 | Cos 0.8816 | Epoch Time 1.12 min | Total Time 95.17 min
# Epoch 86/200 | Loss 0.0011 | Var 1.3570 | Cos 0.8820 | Epoch Time 1.13 min | Total Time 96.30 min
# Epoch 87/200 | Loss 0.0011 | Var 1.3635 | Cos 0.8821 | Epoch Time 1.12 min | Total Time 97.41 min
# Epoch 88/200 | Loss 0.0011 | Var 1.3595 | Cos 0.8816 | Epoch Time 1.11 min | Total Time 98.53 min
# Epoch 89/200 | Loss 0.0011 | Var 1.3553 | Cos 0.8827 | Epoch Time 1.12 min | Total Time 99.65 min
# Epoch 90/200 | Loss 0.0011 | Var 1.3528 | Cos 0.8821 | Epoch Time 1.12 min | Total Time 100.77 min
# Epoch 91/200 | Loss 0.0011 | Var 1.3503 | Cos 0.8816 | Epoch Time 1.12 min | Total Time 101.89 min
# Epoch 92/200 | Loss 0.0011 | Var 1.3502 | Cos 0.8817 | Epoch Time 1.11 min | Total Time 103.00 min
# Epoch 93/200 | Loss 0.0011 | Var 1.3475 | Cos 0.8818 | Epoch Time 1.12 min | Total Time 104.12 min
# Epoch 94/200 | Loss 0.0011 | Var 1.3480 | Cos 0.8817 | Epoch Time 1.12 min | Total Time 105.25 min
# Epoch 95/200 | Loss 0.0011 | Var 1.3448 | Cos 0.8821 | Epoch Time 1.12 min | Total Time 106.37 min
# Epoch 96/200 | Loss 0.0011 | Var 1.3444 | Cos 0.8810 | Epoch Time 1.12 min | Total Time 107.48 min
# Epoch 97/200 | Loss 0.0011 | Var 1.3443 | Cos 0.8805 | Epoch Time 1.13 min | Total Time 108.61 min
# Epoch 98/200 | Loss 0.0011 | Var 1.3404 | Cos 0.8811 | Epoch Time 1.12 min | Total Time 109.73 min
# Epoch 99/200 | Loss 0.0011 | Var 1.3346 | Cos 0.8824 | Epoch Time 1.11 min | Total Time 110.84 min
# Epoch 100/200 | Loss 0.0011 | Var 1.3351 | Cos 0.8819 | Epoch Time 1.11 min | Total Time 111.95 min
# Epoch 101/200 | Loss 0.0011 | Var 1.3379 | Cos 0.8816 | Epoch Time 1.12 min | Total Time 113.07 min
# Epoch 102/200 | Loss 0.0011 | Var 1.3430 | Cos 0.8815 | Epoch Time 1.11 min | Total Time 114.18 min
# Epoch 103/200 | Loss 0.0011 | Var 1.3398 | Cos 0.8813 | Epoch Time 1.11 min | Total Time 115.29 min
# Epoch 104/200 | Loss 0.0011 | Var 1.3358 | Cos 0.8809 | Epoch Time 1.12 min | Total Time 116.41 min
# Epoch 105/200 | Loss 0.0011 | Var 1.3379 | Cos 0.8814 | Epoch Time 1.12 min | Total Time 117.53 min
# Epoch 106/200 | Loss 0.0011 | Var 1.3334 | Cos 0.8812 | Epoch Time 1.11 min | Total Time 118.65 min
# Epoch 107/200 | Loss 0.0011 | Var 1.3275 | Cos 0.8816 | Epoch Time 1.12 min | Total Time 119.76 min
# Epoch 108/200 | Loss 0.0011 | Var 1.3306 | Cos 0.8809 | Epoch Time 1.12 min | Total Time 120.88 min
# Epoch 109/200 | Loss 0.0011 | Var 1.3307 | Cos 0.8813 | Epoch Time 1.12 min | Total Time 121.99 min
# Epoch 110/200 | Loss 0.0011 | Var 1.3289 | Cos 0.8812 | Epoch Time 1.12 min | Total Time 123.11 min
# Epoch 111/200 | Loss 0.0010 | Var 1.3287 | Cos 0.8823 | Epoch Time 1.11 min | Total Time 124.23 min
# Epoch 112/200 | Loss 0.0010 | Var 1.3249 | Cos 0.8818 | Epoch Time 1.13 min | Total Time 125.35 min
# Epoch 113/200 | Loss 0.0011 | Var 1.3323 | Cos 0.8809 | Epoch Time 1.12 min | Total Time 126.47 min
# Epoch 114/200 | Loss 0.0010 | Var 1.3304 | Cos 0.8821 | Epoch Time 1.12 min | Total Time 127.59 min
# Epoch 115/200 | Loss 0.0010 | Var 1.3262 | Cos 0.8823 | Epoch Time 1.11 min | Total Time 128.69 min
# Epoch 116/200 | Loss 0.0010 | Var 1.3207 | Cos 0.8814 | Epoch Time 1.11 min | Total Time 129.80 min
# Epoch 117/200 | Loss 0.0010 | Var 1.3102 | Cos 0.8819 | Epoch Time 1.11 min | Total Time 130.91 min
# Epoch 118/200 | Loss 0.0011 | Var 1.3162 | Cos 0.8805 | Epoch Time 1.12 min | Total Time 132.03 min
# Epoch 119/200 | Loss 0.0011 | Var 1.3154 | Cos 0.8808 | Epoch Time 1.12 min | Total Time 133.15 min
# Epoch 120/200 | Loss 0.0010 | Var 1.3116 | Cos 0.8815 | Epoch Time 1.12 min | Total Time 134.27 min
# Epoch 121/200 | Loss 0.0010 | Var 1.3132 | Cos 0.8811 | Epoch Time 1.12 min | Total Time 135.39 min
# Epoch 122/200 | Loss 0.0010 | Var 1.3151 | Cos 0.8813 | Epoch Time 1.11 min | Total Time 136.51 min
# Epoch 123/200 | Loss 0.0010 | Var 1.3126 | Cos 0.8815 | Epoch Time 1.12 min | Total Time 137.63 min
# Epoch 124/200 | Loss 0.0010 | Var 1.3125 | Cos 0.8809 | Epoch Time 1.12 min | Total Time 138.74 min
# Epoch 125/200 | Loss 0.0010 | Var 1.3126 | Cos 0.8820 | Epoch Time 1.11 min | Total Time 139.86 min
# Epoch 126/200 | Loss 0.0010 | Var 1.3116 | Cos 0.8811 | Epoch Time 1.11 min | Total Time 140.97 min
# Epoch 127/200 | Loss 0.0010 | Var 1.3115 | Cos 0.8798 | Epoch Time 1.12 min | Total Time 142.08 min
# Epoch 128/200 | Loss 0.0010 | Var 1.3118 | Cos 0.8809 | Epoch Time 1.11 min | Total Time 143.19 min
# Epoch 129/200 | Loss 0.0010 | Var 1.3135 | Cos 0.8813 | Epoch Time 1.11 min | Total Time 144.30 min
# Epoch 130/200 | Loss 0.0010 | Var 1.3123 | Cos 0.8809 | Epoch Time 1.12 min | Total Time 145.42 min
# Epoch 131/200 | Loss 0.0010 | Var 1.3053 | Cos 0.8810 | Epoch Time 1.12 min | Total Time 146.54 min
# Epoch 132/200 | Loss 0.0010 | Var 1.3043 | Cos 0.8811 | Epoch Time 1.12 min | Total Time 147.66 min
# Epoch 133/200 | Loss 0.0010 | Var 1.3008 | Cos 0.8809 | Epoch Time 1.13 min | Total Time 148.78 min
# Epoch 134/200 | Loss 0.0010 | Var 1.3037 | Cos 0.8797 | Epoch Time 1.12 min | Total Time 149.91 min
# Epoch 135/200 | Loss 0.0010 | Var 1.3023 | Cos 0.8802 | Epoch Time 1.12 min | Total Time 151.03 min
# Epoch 136/200 | Loss 0.0010 | Var 1.3031 | Cos 0.8799 | Epoch Time 1.11 min | Total Time 152.14 min
# Epoch 137/200 | Loss 0.0010 | Var 1.3037 | Cos 0.8804 | Epoch Time 1.12 min | Total Time 153.26 min
# Epoch 138/200 | Loss 0.0010 | Var 1.3042 | Cos 0.8806 | Epoch Time 1.13 min | Total Time 154.39 min
# Epoch 139/200 | Loss 0.0010 | Var 1.3080 | Cos 0.8803 | Epoch Time 1.12 min | Total Time 155.51 min
# Epoch 140/200 | Loss 0.0010 | Var 1.3058 | Cos 0.8793 | Epoch Time 1.11 min | Total Time 156.63 min
# Epoch 141/200 | Loss 0.0010 | Var 1.3088 | Cos 0.8802 | Epoch Time 1.11 min | Total Time 157.74 min
# Epoch 142/200 | Loss 0.0010 | Var 1.3001 | Cos 0.8801 | Epoch Time 1.12 min | Total Time 158.86 min
# Epoch 143/200 | Loss 0.0010 | Var 1.2982 | Cos 0.8794 | Epoch Time 1.11 min | Total Time 159.97 min
# Epoch 144/200 | Loss 0.0010 | Var 1.3047 | Cos 0.8801 | Epoch Time 1.11 min | Total Time 161.08 min
# Epoch 145/200 | Loss 0.0010 | Var 1.3012 | Cos 0.8791 | Epoch Time 1.12 min | Total Time 162.20 min
# Epoch 146/200 | Loss 0.0010 | Var 1.3035 | Cos 0.8801 | Epoch Time 1.11 min | Total Time 163.31 min
# Epoch 147/200 | Loss 0.0010 | Var 1.3036 | Cos 0.8787 | Epoch Time 1.11 min | Total Time 164.42 min
# Epoch 148/200 | Loss 0.0010 | Var 1.2967 | Cos 0.8795 | Epoch Time 1.11 min | Total Time 165.53 min
# Epoch 149/200 | Loss 0.0010 | Var 1.2952 | Cos 0.8798 | Epoch Time 1.12 min | Total Time 166.65 min
# Epoch 150/200 | Loss 0.0010 | Var 1.3015 | Cos 0.8793 | Epoch Time 1.12 min | Total Time 167.77 min
# Epoch 151/200 | Loss 0.0010 | Var 1.2936 | Cos 0.8789 | Epoch Time 1.12 min | Total Time 168.89 min
# Epoch 152/200 | Loss 0.0010 | Var 1.2904 | Cos 0.8801 | Epoch Time 1.12 min | Total Time 170.01 min
# Epoch 153/200 | Loss 0.0010 | Var 1.2991 | Cos 0.8791 | Epoch Time 1.12 min | Total Time 171.13 min
# Epoch 154/200 | Loss 0.0010 | Var 1.2970 | Cos 0.8791 | Epoch Time 1.12 min | Total Time 172.24 min
# Epoch 155/200 | Loss 0.0010 | Var 1.2941 | Cos 0.8789 | Epoch Time 1.11 min | Total Time 173.36 min
# Epoch 156/200 | Loss 0.0010 | Var 1.2974 | Cos 0.8785 | Epoch Time 1.12 min | Total Time 174.48 min
# Epoch 157/200 | Loss 0.0010 | Var 1.2980 | Cos 0.8783 | Epoch Time 1.11 min | Total Time 175.59 min
# Epoch 158/200 | Loss 0.0010 | Var 1.2989 | Cos 0.8781 | Epoch Time 1.11 min | Total Time 176.70 min
# Epoch 159/200 | Loss 0.0010 | Var 1.2988 | Cos 0.8793 | Epoch Time 1.12 min | Total Time 177.82 min
# Epoch 160/200 | Loss 0.0010 | Var 1.2995 | Cos 0.8783 | Epoch Time 1.11 min | Total Time 178.94 min
# Epoch 161/200 | Loss 0.0010 | Var 1.2931 | Cos 0.8797 | Epoch Time 1.13 min | Total Time 180.07 min
# Epoch 162/200 | Loss 0.0010 | Var 1.2994 | Cos 0.8785 | Epoch Time 1.15 min | Total Time 181.21 min
# Epoch 163/200 | Loss 0.0010 | Var 1.3013 | Cos 0.8782 | Epoch Time 1.13 min | Total Time 182.34 min
# Epoch 164/200 | Loss 0.0010 | Var 1.3017 | Cos 0.8788 | Epoch Time 1.13 min | Total Time 183.47 min
# Epoch 165/200 | Loss 0.0010 | Var 1.2998 | Cos 0.8790 | Epoch Time 1.12 min | Total Time 184.59 min
# Epoch 166/200 | Loss 0.0010 | Var 1.3007 | Cos 0.8774 | Epoch Time 1.13 min | Total Time 185.72 min
# Epoch 167/200 | Loss 0.0010 | Var 1.2966 | Cos 0.8788 | Epoch Time 1.13 min | Total Time 186.85 min
# Epoch 168/200 | Loss 0.0010 | Var 1.2990 | Cos 0.8777 | Epoch Time 1.13 min | Total Time 187.98 min
# Epoch 169/200 | Loss 0.0010 | Var 1.2959 | Cos 0.8780 | Epoch Time 1.13 min | Total Time 189.11 min
# Epoch 170/200 | Loss 0.0010 | Var 1.2926 | Cos 0.8779 | Epoch Time 1.14 min | Total Time 190.25 min
# Epoch 171/200 | Loss 0.0010 | Var 1.2951 | Cos 0.8780 | Epoch Time 1.13 min | Total Time 191.39 min
# Epoch 172/200 | Loss 0.0010 | Var 1.2908 | Cos 0.8777 | Epoch Time 1.13 min | Total Time 192.51 min
# Epoch 173/200 | Loss 0.0010 | Var 1.2916 | Cos 0.8774 | Epoch Time 1.12 min | Total Time 193.63 min
# Epoch 174/200 | Loss 0.0010 | Var 1.2893 | Cos 0.8777 | Epoch Time 1.14 min | Total Time 194.77 min
# Epoch 175/200 | Loss 0.0010 | Var 1.2962 | Cos 0.8765 | Epoch Time 1.13 min | Total Time 195.90 min
# Epoch 176/200 | Loss 0.0010 | Var 1.2909 | Cos 0.8768 | Epoch Time 1.14 min | Total Time 197.03 min
# Epoch 177/200 | Loss 0.0010 | Var 1.2872 | Cos 0.8773 | Epoch Time 1.14 min | Total Time 198.17 min
# Epoch 178/200 | Loss 0.0010 | Var 1.2834 | Cos 0.8773 | Epoch Time 1.14 min | Total Time 199.31 min
# Epoch 179/200 | Loss 0.0010 | Var 1.2879 | Cos 0.8773 | Epoch Time 1.14 min | Total Time 200.45 min
# Epoch 180/200 | Loss 0.0010 | Var 1.2846 | Cos 0.8770 | Epoch Time 1.14 min | Total Time 201.59 min
# Epoch 181/200 | Loss 0.0010 | Var 1.2891 | Cos 0.8778 | Epoch Time 1.13 min | Total Time 202.72 min
# Epoch 182/200 | Loss 0.0010 | Var 1.2902 | Cos 0.8767 | Epoch Time 1.12 min | Total Time 203.84 min
# Epoch 183/200 | Loss 0.0010 | Var 1.2891 | Cos 0.8773 | Epoch Time 1.13 min | Total Time 204.98 min
# Epoch 184/200 | Loss 0.0010 | Var 1.2841 | Cos 0.8771 | Epoch Time 1.13 min | Total Time 206.11 min
# Epoch 185/200 | Loss 0.0010 | Var 1.2837 | Cos 0.8772 | Epoch Time 1.14 min | Total Time 207.25 min
# Epoch 186/200 | Loss 0.0010 | Var 1.2869 | Cos 0.8765 | Epoch Time 1.13 min | Total Time 208.38 min
# Epoch 187/200 | Loss 0.0010 | Var 1.2840 | Cos 0.8770 | Epoch Time 1.12 min | Total Time 209.50 min
# Epoch 188/200 | Loss 0.0010 | Var 1.2803 | Cos 0.8755 | Epoch Time 1.13 min | Total Time 210.63 min
# Epoch 189/200 | Loss 0.0010 | Var 1.2806 | Cos 0.8777 | Epoch Time 1.13 min | Total Time 211.76 min
# Epoch 190/200 | Loss 0.0010 | Var 1.2793 | Cos 0.8767 | Epoch Time 1.12 min | Total Time 212.87 min
# Epoch 191/200 | Loss 0.0010 | Var 1.2783 | Cos 0.8764 | Epoch Time 1.12 min | Total Time 213.99 min
# Epoch 192/200 | Loss 0.0010 | Var 1.2836 | Cos 0.8760 | Epoch Time 1.13 min | Total Time 215.12 min
# Epoch 193/200 | Loss 0.0010 | Var 1.2807 | Cos 0.8759 | Epoch Time 1.13 min | Total Time 216.24 min
# Epoch 194/200 | Loss 0.0010 | Var 1.2761 | Cos 0.8751 | Epoch Time 1.13 min | Total Time 217.37 min
# Epoch 195/200 | Loss 0.0010 | Var 1.2772 | Cos 0.8753 | Epoch Time 1.11 min | Total Time 218.48 min
# Epoch 196/200 | Loss 0.0010 | Var 1.2752 | Cos 0.8753 | Epoch Time 1.12 min | Total Time 219.60 min
# Epoch 197/200 | Loss 0.0010 | Var 1.2739 | Cos 0.8761 | Epoch Time 1.13 min | Total Time 220.73 min
# Epoch 198/200 | Loss 0.0010 | Var 1.2742 | Cos 0.8753 | Epoch Time 1.12 min | Total Time 221.86 min
# Epoch 199/200 | Loss 0.0010 | Var 1.2744 | Cos 0.8758 | Epoch Time 1.12 min | Total Time 222.97 min
# Epoch 200/200 | Loss 0.0010 | Var 1.2739 | Cos 0.8755 | Epoch Time 1.11 min | Total Time 224.08 min

# %%
from torchvision import datasets, transforms

# Probe transform (NO augmentation, only normalization)
probe_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std)
])

train_dataset = datasets.CIFAR10(
    root="/kaggle/working/data",
    train=True,
    download=False,
    transform=probe_transform
)

test_dataset = datasets.CIFAR10(
    root="/kaggle/working/data",
    train=False,
    download=False,
    transform=probe_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=512,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=512,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print("Train batches:", len(train_loader))
print("Test batches:", len(test_loader))
# Out:
# Train batches: 98
# Test batches: 20

# %%
# Load final SSL weights
encoder = Encoder().to(device)
encoder.load_state_dict(torch.load("/kaggle/working/encoder_final.pt"))
encoder.eval()

# Freeze encoder
for p in encoder.parameters():
    p.requires_grad = False

print("Encoder loaded and frozen.")
# Out:
# Encoder loaded and frozen.

# %%
class LinearProbe(nn.Module):
    def __init__(self, in_dim=512, num_classes=10):
        super().__init__()
        self.fc = nn.Linear(in_dim, num_classes)

    def forward(self, x):
        return self.fc(x)


probe = LinearProbe(in_dim=512).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(probe.parameters(), lr=1e-3)

# %%
probe_epochs = 200

for epoch in range(probe_epochs):
    probe.train()
    total_loss = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        with torch.no_grad():
            features = encoder(images)

        outputs = probe(features)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Probe Epoch {epoch+1}/{probe_epochs} | Loss {total_loss/len(train_loader):.4f}")
# Out:
# Probe Epoch 1/200 | Loss 0.9595
# Probe Epoch 2/200 | Loss 0.7687
# Probe Epoch 3/200 | Loss 0.7509
# Probe Epoch 4/200 | Loss 0.7395
# Probe Epoch 5/200 | Loss 0.7311
# Probe Epoch 6/200 | Loss 0.7259
# Probe Epoch 7/200 | Loss 0.7205
# Probe Epoch 8/200 | Loss 0.7166
# Probe Epoch 9/200 | Loss 0.7131
# Probe Epoch 10/200 | Loss 0.7101
# Probe Epoch 11/200 | Loss 0.7069
# Probe Epoch 12/200 | Loss 0.7047
# Probe Epoch 13/200 | Loss 0.7017
# Probe Epoch 14/200 | Loss 0.7003
# Probe Epoch 15/200 | Loss 0.6985
# Probe Epoch 16/200 | Loss 0.6971
# Probe Epoch 17/200 | Loss 0.6958
# Probe Epoch 18/200 | Loss 0.6932
# Probe Epoch 19/200 | Loss 0.6911
# Probe Epoch 20/200 | Loss 0.6888
# Probe Epoch 21/200 | Loss 0.6882
# Probe Epoch 22/200 | Loss 0.6868
# Probe Epoch 23/200 | Loss 0.6855
# Probe Epoch 24/200 | Loss 0.6840
# Probe Epoch 25/200 | Loss 0.6850
# Probe Epoch 26/200 | Loss 0.6826
# Probe Epoch 27/200 | Loss 0.6814
# Probe Epoch 28/200 | Loss 0.6805
# Probe Epoch 29/200 | Loss 0.6793
# Probe Epoch 30/200 | Loss 0.6792
# Probe Epoch 31/200 | Loss 0.6774
# Probe Epoch 32/200 | Loss 0.6761
# Probe Epoch 33/200 | Loss 0.6752
# Probe Epoch 34/200 | Loss 0.6768
# Probe Epoch 35/200 | Loss 0.6747
# Probe Epoch 36/200 | Loss 0.6742
# Probe Epoch 37/200 | Loss 0.6747
# Probe Epoch 38/200 | Loss 0.6746
# Probe Epoch 39/200 | Loss 0.6715
# Probe Epoch 40/200 | Loss 0.6721
# Probe Epoch 41/200 | Loss 0.6711
# Probe Epoch 42/200 | Loss 0.6712
# Probe Epoch 43/200 | Loss 0.6713
# Probe Epoch 44/200 | Loss 0.6697
# Probe Epoch 45/200 | Loss 0.6688
# Probe Epoch 46/200 | Loss 0.6690
# Probe Epoch 47/200 | Loss 0.6687
# Probe Epoch 48/200 | Loss 0.6668
# Probe Epoch 49/200 | Loss 0.6657
# Probe Epoch 50/200 | Loss 0.6664
# Probe Epoch 51/200 | Loss 0.6658
# Probe Epoch 52/200 | Loss 0.6661
# Probe Epoch 53/200 | Loss 0.6660
# Probe Epoch 54/200 | Loss 0.6635
# Probe Epoch 55/200 | Loss 0.6652
# Probe Epoch 56/200 | Loss 0.6644
# Probe Epoch 57/200 | Loss 0.6644
# Probe Epoch 58/200 | Loss 0.6632
# Probe Epoch 59/200 | Loss 0.6643
# Probe Epoch 60/200 | Loss 0.6636
# Probe Epoch 61/200 | Loss 0.6634
# Probe Epoch 62/200 | Loss 0.6629
# Probe Epoch 63/200 | Loss 0.6619
# Probe Epoch 64/200 | Loss 0.6622
# Probe Epoch 65/200 | Loss 0.6614
# Probe Epoch 66/200 | Loss 0.6613
# Probe Epoch 67/200 | Loss 0.6613
# Probe Epoch 68/200 | Loss 0.6611
# Probe Epoch 69/200 | Loss 0.6612
# Probe Epoch 70/200 | Loss 0.6602
# Probe Epoch 71/200 | Loss 0.6589
# Probe Epoch 72/200 | Loss 0.6591
# Probe Epoch 73/200 | Loss 0.6587
# Probe Epoch 74/200 | Loss 0.6585
# Probe Epoch 75/200 | Loss 0.6600
# Probe Epoch 76/200 | Loss 0.6570
# Probe Epoch 77/200 | Loss 0.6580
# Probe Epoch 78/200 | Loss 0.6577
# Probe Epoch 79/200 | Loss 0.6568
# Probe Epoch 80/200 | Loss 0.6562
# Probe Epoch 81/200 | Loss 0.6575
# Probe Epoch 82/200 | Loss 0.6565
# Probe Epoch 83/200 | Loss 0.6569
# Probe Epoch 84/200 | Loss 0.6571
# Probe Epoch 85/200 | Loss 0.6562
# Probe Epoch 86/200 | Loss 0.6559
# Probe Epoch 87/200 | Loss 0.6568
# Probe Epoch 88/200 | Loss 0.6555
# Probe Epoch 89/200 | Loss 0.6551
# Probe Epoch 90/200 | Loss 0.6555
# Probe Epoch 91/200 | Loss 0.6564
# Probe Epoch 92/200 | Loss 0.6562
# Probe Epoch 93/200 | Loss 0.6548
# Probe Epoch 94/200 | Loss 0.6551
# Probe Epoch 95/200 | Loss 0.6550
# Probe Epoch 96/200 | Loss 0.6544
# Probe Epoch 97/200 | Loss 0.6547
# Probe Epoch 98/200 | Loss 0.6541
# Probe Epoch 99/200 | Loss 0.6551
# Probe Epoch 100/200 | Loss 0.6531
# Probe Epoch 101/200 | Loss 0.6555
# Probe Epoch 102/200 | Loss 0.6557
# Probe Epoch 103/200 | Loss 0.6540
# Probe Epoch 104/200 | Loss 0.6527
# Probe Epoch 105/200 | Loss 0.6513
# Probe Epoch 106/200 | Loss 0.6530
# Probe Epoch 107/200 | Loss 0.6533
# Probe Epoch 108/200 | Loss 0.6525
# Probe Epoch 109/200 | Loss 0.6519
# Probe Epoch 110/200 | Loss 0.6528
# Probe Epoch 111/200 | Loss 0.6549
# Probe Epoch 112/200 | Loss 0.6506
# Probe Epoch 113/200 | Loss 0.6506
# Probe Epoch 114/200 | Loss 0.6517
# Probe Epoch 115/200 | Loss 0.6530
# Probe Epoch 116/200 | Loss 0.6523
# Probe Epoch 117/200 | Loss 0.6505
# Probe Epoch 118/200 | Loss 0.6502
# Probe Epoch 119/200 | Loss 0.6502
# Probe Epoch 120/200 | Loss 0.6512
# Probe Epoch 121/200 | Loss 0.6505
# Probe Epoch 122/200 | Loss 0.6503
# Probe Epoch 123/200 | Loss 0.6502
# Probe Epoch 124/200 | Loss 0.6498
# Probe Epoch 125/200 | Loss 0.6496
# Probe Epoch 126/200 | Loss 0.6503
# Probe Epoch 127/200 | Loss 0.6492
# Probe Epoch 128/200 | Loss 0.6498
# Probe Epoch 129/200 | Loss 0.6501
# Probe Epoch 130/200 | Loss 0.6507
# Probe Epoch 131/200 | Loss 0.6498
# Probe Epoch 132/200 | Loss 0.6500
# Probe Epoch 133/200 | Loss 0.6495
# Probe Epoch 134/200 | Loss 0.6485
# Probe Epoch 135/200 | Loss 0.6497
# Probe Epoch 136/200 | Loss 0.6492
# Probe Epoch 137/200 | Loss 0.6489
# Probe Epoch 138/200 | Loss 0.6495
# Probe Epoch 139/200 | Loss 0.6487
# Probe Epoch 140/200 | Loss 0.6489
# Probe Epoch 141/200 | Loss 0.6495
# Probe Epoch 142/200 | Loss 0.6499
# Probe Epoch 143/200 | Loss 0.6487
# Probe Epoch 144/200 | Loss 0.6484
# Probe Epoch 145/200 | Loss 0.6499
# Probe Epoch 146/200 | Loss 0.6485
# Probe Epoch 147/200 | Loss 0.6485
# Probe Epoch 148/200 | Loss 0.6475
# Probe Epoch 149/200 | Loss 0.6484
# Probe Epoch 150/200 | Loss 0.6485
# Probe Epoch 151/200 | Loss 0.6483
# Probe Epoch 152/200 | Loss 0.6479
# Probe Epoch 153/200 | Loss 0.6473
# Probe Epoch 154/200 | Loss 0.6480
# Probe Epoch 155/200 | Loss 0.6489
# Probe Epoch 156/200 | Loss 0.6474
# Probe Epoch 157/200 | Loss 0.6468
# Probe Epoch 158/200 | Loss 0.6481
# Probe Epoch 159/200 | Loss 0.6462
# Probe Epoch 160/200 | Loss 0.6468
# Probe Epoch 161/200 | Loss 0.6468
# Probe Epoch 162/200 | Loss 0.6476
# Probe Epoch 163/200 | Loss 0.6490
# Probe Epoch 164/200 | Loss 0.6478
# Probe Epoch 165/200 | Loss 0.6480
# Probe Epoch 166/200 | Loss 0.6465
# Probe Epoch 167/200 | Loss 0.6463
# Probe Epoch 168/200 | Loss 0.6474
# Probe Epoch 169/200 | Loss 0.6473
# Probe Epoch 170/200 | Loss 0.6458
# Probe Epoch 171/200 | Loss 0.6454
# Probe Epoch 172/200 | Loss 0.6458
# Probe Epoch 173/200 | Loss 0.6463
# Probe Epoch 174/200 | Loss 0.6464
# Probe Epoch 175/200 | Loss 0.6472
# Probe Epoch 176/200 | Loss 0.6447
# Probe Epoch 177/200 | Loss 0.6469
# Probe Epoch 178/200 | Loss 0.6464
# Probe Epoch 179/200 | Loss 0.6457
# Probe Epoch 180/200 | Loss 0.6457
# Probe Epoch 181/200 | Loss 0.6461
# Probe Epoch 182/200 | Loss 0.6460
# Probe Epoch 183/200 | Loss 0.6483
# Probe Epoch 184/200 | Loss 0.6467
# Probe Epoch 185/200 | Loss 0.6453
# Probe Epoch 186/200 | Loss 0.6462
# Probe Epoch 187/200 | Loss 0.6471
# Probe Epoch 188/200 | Loss 0.6453
# Probe Epoch 189/200 | Loss 0.6450
# Probe Epoch 190/200 | Loss 0.6460
# Probe Epoch 191/200 | Loss 0.6479
# Probe Epoch 192/200 | Loss 0.6458
# Probe Epoch 193/200 | Loss 0.6452
# Probe Epoch 194/200 | Loss 0.6443
# Probe Epoch 195/200 | Loss 0.6449
# Probe Epoch 196/200 | Loss 0.6446
# Probe Epoch 197/200 | Loss 0.6445
# Probe Epoch 198/200 | Loss 0.6452
# Probe Epoch 199/200 | Loss 0.6436
# Probe Epoch 200/200 | Loss 0.6446

# %%
probe.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        features = encoder(images)
        outputs = probe(features)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"\n🔹 Linear Probe Test Accuracy: {accuracy:.2f}%")
# Out:
# 🔹 Linear Probe Test Accuracy: 73.47%
