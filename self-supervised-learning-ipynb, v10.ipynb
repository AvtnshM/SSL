# %%
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

cudnn.benchmark = True
# Out:
# Using device: cuda

# %%
base_transform = transforms.ToTensor()

ssl_transform = transforms.Compose([
    transforms.RandomResizedCrop(32),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.4, 0.4, 0.4, 0.1),
    transforms.ToTensor()
])

to_pil = transforms.ToPILImage()

# %%
class BYOLDataset(torch.utils.data.Dataset):
    def __init__(self, root, train, transform):
        self.dataset = datasets.CIFAR10(
            root=root,
            train=train,
            download=True,
            transform=None  # IMPORTANT: no transform here
        )
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, _ = self.dataset[idx]   # img is PIL image
        view1 = self.transform(img)
        view2 = self.transform(img)
        return view1, view2


ssl_dataset = BYOLDataset(
    root="/kaggle/working/data",
    train=True,
    transform=ssl_transform
)

# %%
loader = DataLoader(
    ssl_dataset,
    batch_size=256,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)

print("Batches per epoch:", len(loader))
# Out:
# Batches per epoch: 195

# %%
import torchvision.models as models

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()

        # Load ResNet18
        backbone = models.resnet18(weights=None)

        # Remove final classification layer
        self.encoder = nn.Sequential(*list(backbone.children())[:-1])

    def forward(self, x):
        x = self.encoder(x)
        return x.view(x.size(0), -1)  # Output: (B, 512)

# %%
class Predictor(nn.Module):
    def __init__(self, dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.ReLU(),
            nn.Linear(dim, dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
class Projector(nn.Module):
    def __init__(self, in_dim=512, hidden_dim=512, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
def ssl_loss(p, z):
    p = F.normalize(p, dim=1)
    z = F.normalize(z, dim=1)
    return F.mse_loss(p, z)

# %%
encoder = Encoder().to(device)
projector = Projector().to(device)
predictor = Predictor().to(device)

target_encoder = Encoder().to(device)
target_encoder.load_state_dict(encoder.state_dict())

for p in target_encoder.parameters():
    p.requires_grad = False

optimizer = torch.optim.Adam(
    list(encoder.parameters()) +
    list(projector.parameters()) +
    list(predictor.parameters()),
    lr=1e-3
)

ema_tau = 0.996

# %%
@torch.no_grad()
def feature_variance(z):
    return z.var(dim=0).mean().item()

@torch.no_grad()
def cosine_similarity_mean(z1, z2):
    z1 = F.normalize(z1, dim=1)
    z2 = F.normalize(z2, dim=1)
    return (z1 * z2).sum(dim=1).mean().item()

@torch.no_grad()
def update_target_encoder(online, target, tau):
    for op, tp in zip(online.parameters(), target.parameters()):
        tp.data = tau * tp.data + (1 - tau) * op.data

# %%
epochs = 100
os.makedirs("/kaggle/working/checkpoints", exist_ok=True)

total_start_time = time.time()

for epoch in range(epochs):

    epoch_start = time.time()

    total_loss, total_var, total_cos = 0.0, 0.0, 0.0

    for view1, view2 in loader:

        view1 = view1.to(device)
        view2 = view2.to(device)

        z1 = encoder(view1)
        z2 = encoder(view2)

        h1 = projector(z1)
        h2 = projector(z2)

        p1 = predictor(h1)
        p2 = predictor(h2)

        with torch.no_grad():
            t1 = projector(target_encoder(view1))
            t2 = projector(target_encoder(view2))

        loss = ssl_loss(p1, t2.detach()) + ssl_loss(p2, t1.detach())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        update_target_encoder(encoder, target_encoder, ema_tau)

        with torch.no_grad():
            total_var += feature_variance(z1)
            total_cos += cosine_similarity_mean(z1, z2)

        total_loss += loss.item()

    epoch_time = (time.time() - epoch_start) / 60
    total_time = (time.time() - total_start_time) / 60

    print(
        f"Epoch {epoch+1}/{epochs} | "
        f"Loss {total_loss/len(loader):.4f} | "
        f"Var {total_var/len(loader):.4f} | "
        f"Cos {total_cos/len(loader):.4f} | "
        f"Epoch Time {epoch_time:.2f} min | "
        f"Total Time {total_time:.2f} min"
    )

# Save only final model (avoid 5GB explosion)
torch.save(encoder.state_dict(), "/kaggle/working/encoder_final.pt")
# Out:
# Epoch 1/100 | Loss 0.0008 | Var 2.0752 | Cos 0.6492 | Epoch Time 0.67 min | Total Time 0.67 min
# Epoch 2/100 | Loss 0.0006 | Var 1.9100 | Cos 0.7867 | Epoch Time 0.60 min | Total Time 1.27 min
# Epoch 3/100 | Loss 0.0006 | Var 1.8044 | Cos 0.8376 | Epoch Time 0.60 min | Total Time 1.87 min
# Epoch 4/100 | Loss 0.0007 | Var 1.7897 | Cos 0.8603 | Epoch Time 0.60 min | Total Time 2.47 min
# Epoch 5/100 | Loss 0.0008 | Var 1.7663 | Cos 0.8722 | Epoch Time 0.61 min | Total Time 3.08 min
# Epoch 6/100 | Loss 0.0009 | Var 1.7490 | Cos 0.8795 | Epoch Time 0.60 min | Total Time 3.69 min
# Epoch 7/100 | Loss 0.0009 | Var 1.7558 | Cos 0.8873 | Epoch Time 0.60 min | Total Time 4.29 min
# Epoch 8/100 | Loss 0.0010 | Var 1.7340 | Cos 0.8923 | Epoch Time 0.60 min | Total Time 4.89 min
# Epoch 9/100 | Loss 0.0011 | Var 1.7423 | Cos 0.8966 | Epoch Time 0.60 min | Total Time 5.49 min
# Epoch 10/100 | Loss 0.0011 | Var 1.7369 | Cos 0.9017 | Epoch Time 0.60 min | Total Time 6.09 min
# Epoch 11/100 | Loss 0.0011 | Var 1.7162 | Cos 0.9080 | Epoch Time 0.60 min | Total Time 6.69 min
# Epoch 12/100 | Loss 0.0011 | Var 1.7069 | Cos 0.9086 | Epoch Time 0.60 min | Total Time 7.30 min
# Epoch 13/100 | Loss 0.0012 | Var 1.6781 | Cos 0.9101 | Epoch Time 0.60 min | Total Time 7.90 min
# Epoch 14/100 | Loss 0.0011 | Var 1.6696 | Cos 0.9129 | Epoch Time 0.60 min | Total Time 8.50 min
# Epoch 15/100 | Loss 0.0012 | Var 1.6629 | Cos 0.9144 | Epoch Time 0.60 min | Total Time 9.10 min
# Epoch 16/100 | Loss 0.0012 | Var 1.6315 | Cos 0.9156 | Epoch Time 0.60 min | Total Time 9.70 min
# Epoch 17/100 | Loss 0.0012 | Var 1.6064 | Cos 0.9173 | Epoch Time 0.61 min | Total Time 10.31 min
# Epoch 18/100 | Loss 0.0012 | Var 1.5909 | Cos 0.9198 | Epoch Time 0.61 min | Total Time 10.91 min
# Epoch 19/100 | Loss 0.0012 | Var 1.5803 | Cos 0.9198 | Epoch Time 0.60 min | Total Time 11.52 min
# Epoch 20/100 | Loss 0.0012 | Var 1.5604 | Cos 0.9223 | Epoch Time 0.60 min | Total Time 12.12 min
# Epoch 21/100 | Loss 0.0012 | Var 1.5511 | Cos 0.9235 | Epoch Time 0.60 min | Total Time 12.72 min
# Epoch 22/100 | Loss 0.0011 | Var 1.5384 | Cos 0.9229 | Epoch Time 0.60 min | Total Time 13.32 min
# Epoch 23/100 | Loss 0.0011 | Var 1.5346 | Cos 0.9253 | Epoch Time 0.60 min | Total Time 13.92 min
# Epoch 24/100 | Loss 0.0011 | Var 1.5280 | Cos 0.9257 | Epoch Time 0.60 min | Total Time 14.52 min
# Epoch 25/100 | Loss 0.0011 | Var 1.5126 | Cos 0.9262 | Epoch Time 0.60 min | Total Time 15.12 min
# Epoch 26/100 | Loss 0.0011 | Var 1.4927 | Cos 0.9268 | Epoch Time 0.60 min | Total Time 15.72 min
# Epoch 27/100 | Loss 0.0011 | Var 1.4745 | Cos 0.9270 | Epoch Time 0.60 min | Total Time 16.32 min
# Epoch 28/100 | Loss 0.0011 | Var 1.4728 | Cos 0.9274 | Epoch Time 0.60 min | Total Time 16.92 min
# Epoch 29/100 | Loss 0.0011 | Var 1.4639 | Cos 0.9282 | Epoch Time 0.59 min | Total Time 17.52 min
# Epoch 30/100 | Loss 0.0011 | Var 1.4524 | Cos 0.9282 | Epoch Time 0.60 min | Total Time 18.12 min
# Epoch 31/100 | Loss 0.0011 | Var 1.4546 | Cos 0.9273 | Epoch Time 0.60 min | Total Time 18.72 min
# Epoch 32/100 | Loss 0.0010 | Var 1.4421 | Cos 0.9283 | Epoch Time 0.60 min | Total Time 19.32 min
# Epoch 33/100 | Loss 0.0011 | Var 1.4229 | Cos 0.9269 | Epoch Time 0.60 min | Total Time 19.91 min
# Epoch 34/100 | Loss 0.0011 | Var 1.4111 | Cos 0.9273 | Epoch Time 0.60 min | Total Time 20.51 min
# Epoch 35/100 | Loss 0.0010 | Var 1.4130 | Cos 0.9269 | Epoch Time 0.60 min | Total Time 21.11 min
# Epoch 36/100 | Loss 0.0010 | Var 1.4005 | Cos 0.9270 | Epoch Time 0.60 min | Total Time 21.71 min
# Epoch 37/100 | Loss 0.0010 | Var 1.4080 | Cos 0.9280 | Epoch Time 0.60 min | Total Time 22.30 min
# Epoch 38/100 | Loss 0.0010 | Var 1.3966 | Cos 0.9276 | Epoch Time 0.60 min | Total Time 22.91 min
# Epoch 39/100 | Loss 0.0010 | Var 1.3923 | Cos 0.9276 | Epoch Time 0.60 min | Total Time 23.50 min
# Epoch 40/100 | Loss 0.0010 | Var 1.3806 | Cos 0.9283 | Epoch Time 0.60 min | Total Time 24.10 min
# Epoch 41/100 | Loss 0.0010 | Var 1.3501 | Cos 0.9286 | Epoch Time 0.59 min | Total Time 24.69 min
# Epoch 42/100 | Loss 0.0010 | Var 1.3396 | Cos 0.9285 | Epoch Time 0.59 min | Total Time 25.28 min
# Epoch 43/100 | Loss 0.0010 | Var 1.3440 | Cos 0.9298 | Epoch Time 0.59 min | Total Time 25.88 min
# Epoch 44/100 | Loss 0.0010 | Var 1.3313 | Cos 0.9294 | Epoch Time 0.59 min | Total Time 26.47 min
# Epoch 45/100 | Loss 0.0010 | Var 1.3253 | Cos 0.9294 | Epoch Time 0.59 min | Total Time 27.06 min
# Epoch 46/100 | Loss 0.0010 | Var 1.3265 | Cos 0.9293 | Epoch Time 0.60 min | Total Time 27.66 min
# Epoch 47/100 | Loss 0.0010 | Var 1.3102 | Cos 0.9294 | Epoch Time 0.60 min | Total Time 28.26 min
# Epoch 48/100 | Loss 0.0010 | Var 1.2901 | Cos 0.9307 | Epoch Time 0.60 min | Total Time 28.85 min
# Epoch 49/100 | Loss 0.0010 | Var 1.2823 | Cos 0.9304 | Epoch Time 0.60 min | Total Time 29.45 min
# Epoch 50/100 | Loss 0.0009 | Var 1.2778 | Cos 0.9310 | Epoch Time 0.59 min | Total Time 30.04 min
# Epoch 51/100 | Loss 0.0009 | Var 1.2710 | Cos 0.9314 | Epoch Time 0.60 min | Total Time 30.64 min
# Epoch 52/100 | Loss 0.0009 | Var 1.2668 | Cos 0.9320 | Epoch Time 0.60 min | Total Time 31.24 min
# Epoch 53/100 | Loss 0.0009 | Var 1.2609 | Cos 0.9319 | Epoch Time 0.60 min | Total Time 31.84 min
# Epoch 54/100 | Loss 0.0009 | Var 1.2439 | Cos 0.9305 | Epoch Time 0.59 min | Total Time 32.43 min
# Epoch 55/100 | Loss 0.0009 | Var 1.2216 | Cos 0.9314 | Epoch Time 0.59 min | Total Time 33.02 min
# Epoch 56/100 | Loss 0.0009 | Var 1.2153 | Cos 0.9317 | Epoch Time 0.59 min | Total Time 33.61 min
# Epoch 57/100 | Loss 0.0009 | Var 1.2177 | Cos 0.9320 | Epoch Time 0.60 min | Total Time 34.21 min
# Epoch 58/100 | Loss 0.0009 | Var 1.2176 | Cos 0.9317 | Epoch Time 0.60 min | Total Time 34.81 min
# Epoch 59/100 | Loss 0.0009 | Var 1.2100 | Cos 0.9322 | Epoch Time 0.60 min | Total Time 35.40 min
# Epoch 60/100 | Loss 0.0009 | Var 1.2055 | Cos 0.9322 | Epoch Time 0.59 min | Total Time 36.00 min
# Epoch 61/100 | Loss 0.0009 | Var 1.1984 | Cos 0.9318 | Epoch Time 0.60 min | Total Time 36.59 min
# Epoch 62/100 | Loss 0.0009 | Var 1.1921 | Cos 0.9319 | Epoch Time 0.60 min | Total Time 37.19 min
# Epoch 63/100 | Loss 0.0009 | Var 1.1816 | Cos 0.9315 | Epoch Time 0.59 min | Total Time 37.78 min
# Epoch 64/100 | Loss 0.0009 | Var 1.1762 | Cos 0.9326 | Epoch Time 0.59 min | Total Time 38.38 min
# Epoch 65/100 | Loss 0.0009 | Var 1.1715 | Cos 0.9321 | Epoch Time 0.60 min | Total Time 38.97 min
# Epoch 66/100 | Loss 0.0009 | Var 1.1683 | Cos 0.9315 | Epoch Time 0.60 min | Total Time 39.57 min
# Epoch 67/100 | Loss 0.0009 | Var 1.1630 | Cos 0.9326 | Epoch Time 0.59 min | Total Time 40.16 min
# Epoch 68/100 | Loss 0.0009 | Var 1.1480 | Cos 0.9318 | Epoch Time 0.60 min | Total Time 40.76 min
# Epoch 69/100 | Loss 0.0009 | Var 1.1539 | Cos 0.9316 | Epoch Time 0.59 min | Total Time 41.35 min
# Epoch 70/100 | Loss 0.0009 | Var 1.1504 | Cos 0.9316 | Epoch Time 0.59 min | Total Time 41.94 min
# Epoch 71/100 | Loss 0.0009 | Var 1.1361 | Cos 0.9316 | Epoch Time 0.59 min | Total Time 42.54 min
# Epoch 72/100 | Loss 0.0009 | Var 1.1398 | Cos 0.9317 | Epoch Time 0.59 min | Total Time 43.13 min
# Epoch 73/100 | Loss 0.0009 | Var 1.1340 | Cos 0.9321 | Epoch Time 0.59 min | Total Time 43.72 min
# Epoch 74/100 | Loss 0.0009 | Var 1.1240 | Cos 0.9316 | Epoch Time 0.59 min | Total Time 44.31 min
# Epoch 75/100 | Loss 0.0009 | Var 1.1112 | Cos 0.9328 | Epoch Time 0.59 min | Total Time 44.90 min
# Epoch 76/100 | Loss 0.0009 | Var 1.1115 | Cos 0.9318 | Epoch Time 0.59 min | Total Time 45.49 min
# Epoch 77/100 | Loss 0.0008 | Var 1.1078 | Cos 0.9326 | Epoch Time 0.59 min | Total Time 46.09 min
# Epoch 78/100 | Loss 0.0008 | Var 1.1028 | Cos 0.9322 | Epoch Time 0.59 min | Total Time 46.68 min
# Epoch 79/100 | Loss 0.0009 | Var 1.0883 | Cos 0.9321 | Epoch Time 0.59 min | Total Time 47.27 min
# Epoch 80/100 | Loss 0.0009 | Var 1.0800 | Cos 0.9322 | Epoch Time 0.59 min | Total Time 47.87 min
# Epoch 81/100 | Loss 0.0008 | Var 1.0824 | Cos 0.9327 | Epoch Time 0.59 min | Total Time 48.46 min
# Epoch 82/100 | Loss 0.0008 | Var 1.0851 | Cos 0.9330 | Epoch Time 0.59 min | Total Time 49.05 min
# Epoch 83/100 | Loss 0.0008 | Var 1.0805 | Cos 0.9335 | Epoch Time 0.60 min | Total Time 49.65 min
# Epoch 84/100 | Loss 0.0009 | Var 1.0750 | Cos 0.9318 | Epoch Time 0.60 min | Total Time 50.24 min
# Epoch 85/100 | Loss 0.0008 | Var 1.0688 | Cos 0.9330 | Epoch Time 0.59 min | Total Time 50.84 min
# Epoch 86/100 | Loss 0.0008 | Var 1.0630 | Cos 0.9326 | Epoch Time 0.60 min | Total Time 51.43 min
# Epoch 87/100 | Loss 0.0009 | Var 1.0566 | Cos 0.9329 | Epoch Time 0.59 min | Total Time 52.02 min
# Epoch 88/100 | Loss 0.0008 | Var 1.0540 | Cos 0.9333 | Epoch Time 0.59 min | Total Time 52.61 min
# Epoch 89/100 | Loss 0.0008 | Var 1.0571 | Cos 0.9339 | Epoch Time 0.59 min | Total Time 53.21 min
# Epoch 90/100 | Loss 0.0008 | Var 1.0523 | Cos 0.9332 | Epoch Time 0.60 min | Total Time 53.80 min
# Epoch 91/100 | Loss 0.0008 | Var 1.0541 | Cos 0.9339 | Epoch Time 0.60 min | Total Time 54.40 min
# Epoch 92/100 | Loss 0.0008 | Var 1.0503 | Cos 0.9334 | Epoch Time 0.59 min | Total Time 54.99 min
# Epoch 93/100 | Loss 0.0008 | Var 1.0441 | Cos 0.9337 | Epoch Time 0.59 min | Total Time 55.58 min
# Epoch 94/100 | Loss 0.0008 | Var 1.0361 | Cos 0.9327 | Epoch Time 0.59 min | Total Time 56.18 min
# Epoch 95/100 | Loss 0.0008 | Var 1.0364 | Cos 0.9334 | Epoch Time 0.59 min | Total Time 56.76 min
# Epoch 96/100 | Loss 0.0008 | Var 1.0311 | Cos 0.9336 | Epoch Time 0.59 min | Total Time 57.35 min
# Epoch 97/100 | Loss 0.0008 | Var 1.0313 | Cos 0.9340 | Epoch Time 0.59 min | Total Time 57.95 min
# Epoch 98/100 | Loss 0.0008 | Var 1.0243 | Cos 0.9337 | Epoch Time 0.59 min | Total Time 58.54 min
# Epoch 99/100 | Loss 0.0008 | Var 1.0202 | Cos 0.9335 | Epoch Time 0.59 min | Total Time 59.13 min
# Epoch 100/100 | Loss 0.0008 | Var 1.0184 | Cos 0.9334 | Epoch Time 0.59 min | Total Time 59.72 min

# %%
from torchvision import datasets, transforms

# No augmentation for probe
probe_transform = transforms.ToTensor()

train_dataset = datasets.CIFAR10(
    root="/kaggle/working/data",
    train=True,
    download=False,
    transform=probe_transform
)

test_dataset = datasets.CIFAR10(
    root="/kaggle/working/data",
    train=False,
    download=False,
    transform=probe_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=256,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print("Train batches:", len(train_loader))
print("Test batches:", len(test_loader))
# Out:
# Train batches: 196
# Test batches: 40

# %%
# Load final SSL weights
encoder = Encoder().to(device)
encoder.load_state_dict(torch.load("/kaggle/working/encoder_final.pt"))
encoder.eval()

# Freeze encoder
for p in encoder.parameters():
    p.requires_grad = False

print("Encoder loaded and frozen.")
# Out:
# Encoder loaded and frozen.

# %%
class LinearProbe(nn.Module):
    def __init__(self, in_dim=512, num_classes=10):
        super().__init__()
        self.fc = nn.Linear(in_dim, num_classes)

    def forward(self, x):
        return self.fc(x)


probe = LinearProbe(in_dim=512).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(probe.parameters(), lr=1e-3)

# %%
probe_epochs = 100

for epoch in range(probe_epochs):
    probe.train()
    total_loss = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        with torch.no_grad():
            features = encoder(images)

        outputs = probe(features)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Probe Epoch {epoch+1}/{probe_epochs} | Loss {total_loss/len(train_loader):.4f}")
# Out:
# Probe Epoch 1/100 | Loss 1.5763
# Probe Epoch 2/100 | Loss 1.4768
# Probe Epoch 3/100 | Loss 1.4473
# Probe Epoch 4/100 | Loss 1.4337
# Probe Epoch 5/100 | Loss 1.4230
# Probe Epoch 6/100 | Loss 1.4150
# Probe Epoch 7/100 | Loss 1.4080
# Probe Epoch 8/100 | Loss 1.4033
# Probe Epoch 9/100 | Loss 1.3948
# Probe Epoch 10/100 | Loss 1.3945
# Probe Epoch 11/100 | Loss 1.3868
# Probe Epoch 12/100 | Loss 1.3845
# Probe Epoch 13/100 | Loss 1.3819
# Probe Epoch 14/100 | Loss 1.3772
# Probe Epoch 15/100 | Loss 1.3762
# Probe Epoch 16/100 | Loss 1.3745
# Probe Epoch 17/100 | Loss 1.3713
# Probe Epoch 18/100 | Loss 1.3671
# Probe Epoch 19/100 | Loss 1.3645
# Probe Epoch 20/100 | Loss 1.3642
# Probe Epoch 21/100 | Loss 1.3648
# Probe Epoch 22/100 | Loss 1.3601
# Probe Epoch 23/100 | Loss 1.3588
# Probe Epoch 24/100 | Loss 1.3550
# Probe Epoch 25/100 | Loss 1.3573
# Probe Epoch 26/100 | Loss 1.3558
# Probe Epoch 27/100 | Loss 1.3559
# Probe Epoch 28/100 | Loss 1.3521
# Probe Epoch 29/100 | Loss 1.3531
# Probe Epoch 30/100 | Loss 1.3502
# Probe Epoch 31/100 | Loss 1.3472
# Probe Epoch 32/100 | Loss 1.3464
# Probe Epoch 33/100 | Loss 1.3452
# Probe Epoch 34/100 | Loss 1.3433
# Probe Epoch 35/100 | Loss 1.3435
# Probe Epoch 36/100 | Loss 1.3463
# Probe Epoch 37/100 | Loss 1.3399
# Probe Epoch 38/100 | Loss 1.3415
# Probe Epoch 39/100 | Loss 1.3382
# Probe Epoch 40/100 | Loss 1.3374
# Probe Epoch 41/100 | Loss 1.3367
# Probe Epoch 42/100 | Loss 1.3405
# Probe Epoch 43/100 | Loss 1.3358
# Probe Epoch 44/100 | Loss 1.3346
# Probe Epoch 45/100 | Loss 1.3343
# Probe Epoch 46/100 | Loss 1.3329
# Probe Epoch 47/100 | Loss 1.3356
# Probe Epoch 48/100 | Loss 1.3365
# Probe Epoch 49/100 | Loss 1.3313
# Probe Epoch 50/100 | Loss 1.3296
# Probe Epoch 51/100 | Loss 1.3316
# Probe Epoch 52/100 | Loss 1.3306
# Probe Epoch 53/100 | Loss 1.3280
# Probe Epoch 54/100 | Loss 1.3285
# Probe Epoch 55/100 | Loss 1.3292
# Probe Epoch 56/100 | Loss 1.3282
# Probe Epoch 57/100 | Loss 1.3281
# Probe Epoch 58/100 | Loss 1.3253
# Probe Epoch 59/100 | Loss 1.3266
# Probe Epoch 60/100 | Loss 1.3261
# Probe Epoch 61/100 | Loss 1.3243
# Probe Epoch 62/100 | Loss 1.3220
# Probe Epoch 63/100 | Loss 1.3233
# Probe Epoch 64/100 | Loss 1.3227
# Probe Epoch 65/100 | Loss 1.3211
# Probe Epoch 66/100 | Loss 1.3205
# Probe Epoch 67/100 | Loss 1.3223
# Probe Epoch 68/100 | Loss 1.3228
# Probe Epoch 69/100 | Loss 1.3202
# Probe Epoch 70/100 | Loss 1.3200
# Probe Epoch 71/100 | Loss 1.3206
# Probe Epoch 72/100 | Loss 1.3201
# Probe Epoch 73/100 | Loss 1.3209
# Probe Epoch 74/100 | Loss 1.3185
# Probe Epoch 75/100 | Loss 1.3196
# Probe Epoch 76/100 | Loss 1.3179
# Probe Epoch 77/100 | Loss 1.3180
# Probe Epoch 78/100 | Loss 1.3156
# Probe Epoch 79/100 | Loss 1.3193
# Probe Epoch 80/100 | Loss 1.3157
# Probe Epoch 81/100 | Loss 1.3147
# Probe Epoch 82/100 | Loss 1.3172
# Probe Epoch 83/100 | Loss 1.3148
# Probe Epoch 84/100 | Loss 1.3174
# Probe Epoch 85/100 | Loss 1.3119
# Probe Epoch 86/100 | Loss 1.3129
# Probe Epoch 87/100 | Loss 1.3123
# Probe Epoch 88/100 | Loss 1.3139
# Probe Epoch 89/100 | Loss 1.3128
# Probe Epoch 90/100 | Loss 1.3150
# Probe Epoch 91/100 | Loss 1.3123
# Probe Epoch 92/100 | Loss 1.3111
# Probe Epoch 93/100 | Loss 1.3118
# Probe Epoch 94/100 | Loss 1.3109
# Probe Epoch 95/100 | Loss 1.3108
# Probe Epoch 96/100 | Loss 1.3093
# Probe Epoch 97/100 | Loss 1.3074
# Probe Epoch 98/100 | Loss 1.3116
# Probe Epoch 99/100 | Loss 1.3114
# Probe Epoch 100/100 | Loss 1.3081

# %%
probe.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        features = encoder(images)
        outputs = probe(features)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"\n🔹 Linear Probe Test Accuracy: {accuracy:.2f}%")
# Out:
# 🔹 Linear Probe Test Accuracy: 50.67%
